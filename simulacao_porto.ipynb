# %%
import simpy
import random
import numpy as np
import pandas as pd
from datetime import timedelta

# Configuração da simulação
NUM_TERMINALS = 20
SHIP_ARRIVAL_RATE = 5  # navios por dia
SIM_DURATION = 30  # dias de simulação

# Distribuição de destino dos navios (exemplo: 50% dos navios vão para os 5 primeiros terminais)
DESTINATION_PROBS = [0.08] * 5 + [0.06] * 5 + [0.04] * 5 + [0.02] * 5

# Parâmetros do tempo de serviço por terminal (distribuição triangular)
SERVICE_TIMES = {i: (4, 8, 6) for i in range(NUM_TERMINALS)}  # (min, max, modo)

# Listas para armazenar resultados
ship_log = []
terminal_log = []

class Porto:
    def __init__(self, env):
        self.env = env
        self.terminals = {i: simpy.Resource(env, capacity=1) for i in range(NUM_TERMINALS)}
        self.terminal_status = {i: {'start': None, 'idle_time': 0} for i in range(NUM_TERMINALS)}

    def service(self, ship_id, arrival_time, terminal_id, duration_params):
        with self.terminals[terminal_id].request() as req:
            yield req  # Aguarda o terminal ficar disponível

            # Registra início do uso do terminal
            if self.terminal_status[terminal_id]['start'] is None:
                self.terminal_status[terminal_id]['start'] = self.env.now
            else:
                idle_time = self.env.now - self.terminal_status[terminal_id]['start']
                self.terminal_status[terminal_id]['idle_time'] += idle_time

            start_time = self.env.now
            print(f'Navio {ship_id} começou a ser atendido no terminal {terminal_id} em {start_time:.2f} horas')

            # Gera duração do serviço
            duration = random.triangular(*duration_params)
            yield self.env.timeout(duration)

            end_time = self.env.now
            print(f'Navio {ship_id} terminou em {end_time:.2f} horas | Tempo de fila: {(start_time - arrival_time):.2f}, Tempo de serviço: {duration:.2f}')

            # Armazena resultados
            ship_log.append({
                'ID Navio': ship_id,
                'Terminal': terminal_id,
                'Chegada': arrival_time,
                'Início Serviço': start_time,
                'Fila (h)': start_time - arrival_time,
                'Duração Serviço': duration,
                'Término': end_time
            })

            # Atualiza status do terminal
            self.terminal_status[terminal_id]['start'] = None

def ship_generator(env, porto):
    ship_id = 0
    while True:
        # Intervalo entre chegadas (Poisson)
        interarrival_time = random.expovariate(SHIP_ARRIVAL_RATE / 24)  # convertendo para horas
        yield env.timeout(interarrival_time)

        ship_id += 1
        destination = np.random.choice(range(NUM_TERMINALS), p=DESTINATION_PROBS)
        duration_params = SERVICE_TIMES[destination]

        arrival_time = env.now
        print(f'Navio {ship_id} chegou no porto em {arrival_time:.2f} horas')
    
        env.process(porto.service(ship_id, arrival_time, destination, duration_params))

def run_simulation():
    env = simpy.Environment()
    porto = Porto(env)
    env.process(ship_generator(env, porto))
    env.run(until=SIM_DURATION * 24)  # Converte dias para horas

    # DataFrame com logs dos navios
    df_ships = pd.DataFrame(ship_log)
    df_terminals = []

    for term_id, log in porto.terminal_status.items():
        df_terminals.append({
            'Terminal': term_id,
            'Tempo Ocioso (h)': log['idle_time'],
            'Tempo Total (h)': SIM_DURATION * 24,
            'Ocupação (%)': ((SIM_DURATION * 24 - log['idle_time']) / (SIM_DURATION * 24)) * 100
        })

    df_terminals = pd.DataFrame(df_terminals)

    return df_ships, df_terminals

# Roda a simulação
df_ships, df_terminals = run_simulation()

# Mostra resultados
print("\nLogs dos navios:")
display(df_ships.head(10).style.format(precision=2))

print("\nLogs dos terminais:")
display(df_terminals.style.format(precision=2))
# Out:
# Navio 1 chegou no porto em 2.94 horas
# Navio 1 começou a ser atendido no terminal 13 em 2.94 horas
# Navio 1 terminou em 8.04 horas | Tempo de fila: 0.00, Tempo de serviço: 5.10
# Navio 2 chegou no porto em 14.61 horas
# Navio 2 começou a ser atendido no terminal 10 em 14.61 horas
# Navio 3 chegou no porto em 15.25 horas
# Navio 3 começou a ser atendido no terminal 6 em 15.25 horas
# Navio 3 terminou em 19.54 horas | Tempo de fila: 0.00, Tempo de serviço: 4.29
# Navio 2 terminou em 20.04 horas | Tempo de fila: 0.00, Tempo de serviço: 5.43
# Navio 4 chegou no porto em 40.97 horas
# Navio 4 começou a ser atendido no terminal 12 em 40.97 horas
# Navio 4 terminou em 46.21 horas | Tempo de fila: 0.00, Tempo de serviço: 5.23
# Navio 5 chegou no porto em 48.46 horas
# Navio 5 começou a ser atendido no terminal 5 em 48.46 horas
# Navio 6 chegou no porto em 48.46 horas
# Navio 6 começou a ser atendido no terminal 0 em 48.46 horas
# Navio 7 chegou no porto em 52.56 horas
# Navio 7 começou a ser atendido no terminal 4 em 52.56 horas
# Navio 6 terminou em 53.19 horas | Tempo de fila: 0.00, Tempo de serviço: 4.73
# Navio 5 terminou em 53.48 horas | Tempo de fila: 0.00, Tempo de serviço: 5.03
# Navio 8 chegou no porto em 55.58 horas
# Navio 8 começou a ser atendido no terminal 1 em 55.58 horas
# Navio 7 terminou em 58.43 horas | Tempo de fila: 0.00, Tempo de serviço: 5.87
# Navio 8 terminou em 60.92 horas | Tempo de fila: 0.00, Tempo de serviço: 5.34
# Navio 9 chegou no porto em 63.49 horas
# Navio 9 começou a ser atendido no terminal 0 em 63.49 horas
# Navio 9 terminou em 69.25 horas | Tempo de fila: 0.00, Tempo de serviço: 5.76
# Navio 10 chegou no porto em 72.76 horas
# Navio 10 começou a ser atendido no terminal 3 em 72.76 horas
# Navio 11 chegou no porto em 75.76 horas
# Navio 11 começou a ser atendido no terminal 8 em 75.76 horas
# Navio 12 chegou no porto em 77.33 horas
# Navio 12 começou a ser atendido no terminal 7 em 77.33 horas
# Navio 10 terminou em 79.42 horas | Tempo de fila: 0.00, Tempo de serviço: 6.65
# Navio 13 chegou no porto em 80.07 horas
# Navio 13 começou a ser atendido no terminal 1 em 80.07 horas
# Navio 11 terminou em 81.85 horas | Tempo de fila: 0.00, Tempo de serviço: 6.09
# Navio 12 terminou em 82.57 horas | Tempo de fila: 0.00, Tempo de serviço: 5.24
# Navio 13 terminou em 85.17 horas | Tempo de fila: 0.00, Tempo de serviço: 5.11
# Navio 14 chegou no porto em 87.37 horas
# Navio 14 começou a ser atendido no terminal 14 em 87.37 horas
# Navio 14 terminou em 93.45 horas | Tempo de fila: 0.00, Tempo de serviço: 6.09
# Navio 15 chegou no porto em 97.07 horas
# Navio 15 começou a ser atendido no terminal 10 em 97.07 horas
# Navio 15 terminou em 103.44 horas | Tempo de fila: 0.00, Tempo de serviço: 6.37
# Navio 16 chegou no porto em 112.01 horas
# Navio 16 começou a ser atendido no terminal 9 em 112.01 horas
# Navio 16 terminou em 118.69 horas | Tempo de fila: 0.00, Tempo de serviço: 6.68
# Navio 17 chegou no porto em 123.98 horas
# Navio 17 começou a ser atendido no terminal 0 em 123.98 horas
# Navio 18 chegou no porto em 124.51 horas
# Navio 18 começou a ser atendido no terminal 4 em 124.51 horas
# Navio 17 terminou em 129.31 horas | Tempo de fila: 0.00, Tempo de serviço: 5.33
# Navio 18 terminou em 131.72 horas | Tempo de fila: 0.00, Tempo de serviço: 7.21
# Navio 19 chegou no porto em 133.63 horas
# Navio 19 começou a ser atendido no terminal 1 em 133.63 horas
# Navio 20 chegou no porto em 136.29 horas
# Navio 20 começou a ser atendido no terminal 0 em 136.29 horas
# Navio 21 chegou no porto em 137.88 horas
# Navio 21 começou a ser atendido no terminal 4 em 137.88 horas
# Navio 19 terminou em 138.94 horas | Tempo de fila: 0.00, Tempo de serviço: 5.31
# Navio 22 chegou no porto em 139.12 horas
# Navio 21 terminou em 143.15 horas | Tempo de fila: 0.00, Tempo de serviço: 5.26
# Navio 22 começou a ser atendido no terminal 4 em 143.15 horas
# Navio 20 terminou em 143.58 horas | Tempo de fila: 0.00, Tempo de serviço: 7.29
# Navio 22 terminou em 148.79 horas | Tempo de fila: 4.03, Tempo de serviço: 5.65
# Navio 23 chegou no porto em 153.11 horas
# Navio 23 começou a ser atendido no terminal 5 em 153.11 horas
# Navio 24 chegou no porto em 154.77 horas
# Navio 24 começou a ser atendido no terminal 2 em 154.77 horas
# Navio 23 terminou em 157.84 horas | Tempo de fila: 0.00, Tempo de serviço: 4.72
# Navio 24 terminou em 160.64 horas | Tempo de fila: 0.00, Tempo de serviço: 5.88
# Navio 25 chegou no porto em 170.18 horas
# Navio 25 começou a ser atendido no terminal 5 em 170.18 horas
# Navio 25 terminou em 176.71 horas | Tempo de fila: 0.00, Tempo de serviço: 6.53
# Navio 26 chegou no porto em 185.41 horas
# Navio 26 começou a ser atendido no terminal 5 em 185.41 horas
# Navio 27 chegou no porto em 185.64 horas
# Navio 27 começou a ser atendido no terminal 10 em 185.64 horas
# Navio 26 terminou em 191.42 horas | Tempo de fila: 0.00, Tempo de serviço: 6.01
# Navio 28 chegou no porto em 191.53 horas
# Navio 28 começou a ser atendido no terminal 0 em 191.53 horas
# Navio 27 terminou em 191.60 horas | Tempo de fila: 0.00, Tempo de serviço: 5.96
# Navio 28 terminou em 198.14 horas | Tempo de fila: 0.00, Tempo de serviço: 6.61
# Navio 29 chegou no porto em 215.97 horas
# Navio 29 começou a ser atendido no terminal 15 em 215.97 horas
# Navio 29 terminou em 221.19 horas | Tempo de fila: 0.00, Tempo de serviço: 5.21
# Navio 30 chegou no porto em 223.77 horas
# Navio 30 começou a ser atendido no terminal 6 em 223.77 horas
# Navio 31 chegou no porto em 225.59 horas
# Navio 31 começou a ser atendido no terminal 9 em 225.59 horas
# Navio 32 chegou no porto em 226.15 horas
# Navio 33 chegou no porto em 227.36 horas
# Navio 33 começou a ser atendido no terminal 16 em 227.36 horas
# Navio 30 terminou em 228.63 horas | Tempo de fila: 0.00, Tempo de serviço: 4.86
# Navio 34 chegou no porto em 229.74 horas
# Navio 33 terminou em 231.55 horas | Tempo de fila: 0.00, Tempo de serviço: 4.19
# Navio 35 chegou no porto em 231.82 horas
# Navio 35 começou a ser atendido no terminal 4 em 231.82 horas
# Navio 31 terminou em 232.11 horas | Tempo de fila: 0.00, Tempo de serviço: 6.52
# Navio 32 começou a ser atendido no terminal 9 em 232.11 horas
# Navio 36 chegou no porto em 234.27 horas
# Navio 36 começou a ser atendido no terminal 0 em 234.27 horas
# Navio 35 terminou em 236.47 horas | Tempo de fila: 0.00, Tempo de serviço: 4.65
# Navio 32 terminou em 237.35 horas | Tempo de fila: 5.97, Tempo de serviço: 5.23
# Navio 34 começou a ser atendido no terminal 9 em 237.35 horas
# Navio 37 chegou no porto em 238.20 horas
# Navio 37 começou a ser atendido no terminal 3 em 238.20 horas
# Navio 36 terminou em 239.75 horas | Tempo de fila: 0.00, Tempo de serviço: 5.48
# Navio 38 chegou no porto em 239.96 horas
# Navio 38 começou a ser atendido no terminal 6 em 239.96 horas
# Navio 34 terminou em 243.30 horas | Tempo de fila: 7.60, Tempo de serviço: 5.96
# Navio 39 chegou no porto em 245.14 horas
# Navio 39 começou a ser atendido no terminal 10 em 245.14 horas
# Navio 37 terminou em 245.29 horas | Tempo de fila: 0.00, Tempo de serviço: 7.09
# Navio 38 terminou em 247.03 horas | Tempo de fila: 0.00, Tempo de serviço: 7.07
# Navio 39 terminou em 250.15 horas | Tempo de fila: 0.00, Tempo de serviço: 5.01
# Navio 40 chegou no porto em 254.81 horas
# Navio 40 começou a ser atendido no terminal 9 em 254.81 horas
# Navio 41 chegou no porto em 255.80 horas
# Navio 41 começou a ser atendido no terminal 14 em 255.80 horas
# Navio 41 terminou em 261.70 horas | Tempo de fila: 0.00, Tempo de serviço: 5.90
# Navio 42 chegou no porto em 261.81 horas
# Navio 42 começou a ser atendido no terminal 14 em 261.81 horas
# Navio 40 terminou em 262.04 horas | Tempo de fila: 0.00, Tempo de serviço: 7.22
# Navio 43 chegou no porto em 266.25 horas
# Navio 43 começou a ser atendido no terminal 4 em 266.25 horas
# Navio 42 terminou em 268.62 horas | Tempo de fila: 0.00, Tempo de serviço: 6.81
# Navio 43 terminou em 272.80 horas | Tempo de fila: 0.00, Tempo de serviço: 6.54
# Navio 44 chegou no porto em 274.76 horas
# Navio 44 começou a ser atendido no terminal 4 em 274.76 horas
# Navio 45 chegou no porto em 279.29 horas
# Navio 44 terminou em 279.84 horas | Tempo de fila: 0.00, Tempo de serviço: 5.08
# Navio 45 começou a ser atendido no terminal 4 em 279.84 horas
# Navio 45 terminou em 286.37 horas | Tempo de fila: 0.55, Tempo de serviço: 6.53
# Navio 46 chegou no porto em 289.01 horas
# Navio 46 começou a ser atendido no terminal 8 em 289.01 horas
# Navio 47 chegou no porto em 292.47 horas
# Navio 47 começou a ser atendido no terminal 13 em 292.47 horas
# Navio 46 terminou em 294.02 horas | Tempo de fila: 0.00, Tempo de serviço: 5.01
# Navio 48 chegou no porto em 294.41 horas
# Navio 48 começou a ser atendido no terminal 9 em 294.41 horas
# Navio 49 chegou no porto em 294.66 horas
# Navio 49 começou a ser atendido no terminal 10 em 294.66 horas
# Navio 47 terminou em 299.67 horas | Tempo de fila: 0.00, Tempo de serviço: 7.20
# Navio 48 terminou em 301.30 horas | Tempo de fila: 0.00, Tempo de serviço: 6.89
# Navio 49 terminou em 301.78 horas | Tempo de fila: 0.00, Tempo de serviço: 7.11
# Navio 50 chegou no porto em 305.14 horas
# Navio 50 começou a ser atendido no terminal 15 em 305.14 horas
# Navio 51 chegou no porto em 309.37 horas
# Navio 51 começou a ser atendido no terminal 5 em 309.37 horas
# Navio 50 terminou em 311.11 horas | Tempo de fila: 0.00, Tempo de serviço: 5.97
# Navio 52 chegou no porto em 311.29 horas
# Navio 52 começou a ser atendido no terminal 7 em 311.29 horas
# Navio 51 terminou em 315.85 horas | Tempo de fila: 0.00, Tempo de serviço: 6.48
# Navio 53 chegou no porto em 317.67 horas
# Navio 53 começou a ser atendido no terminal 14 em 317.67 horas
# Navio 54 chegou no porto em 317.79 horas
# Navio 54 começou a ser atendido no terminal 5 em 317.79 horas
# Navio 52 terminou em 317.99 horas | Tempo de fila: 0.00, Tempo de serviço: 6.70
# Navio 55 chegou no porto em 320.25 horas
# Navio 55 começou a ser atendido no terminal 13 em 320.25 horas
# Navio 53 terminou em 324.00 horas | Tempo de fila: 0.00, Tempo de serviço: 6.33
# Navio 54 terminou em 324.31 horas | Tempo de fila: 0.00, Tempo de serviço: 6.52
# Navio 55 terminou em 326.31 horas | Tempo de fila: 0.00, Tempo de serviço: 6.05
# Navio 56 chegou no porto em 330.68 horas
# Navio 56 começou a ser atendido no terminal 11 em 330.68 horas
# Navio 57 chegou no porto em 332.40 horas
# Navio 57 começou a ser atendido no terminal 14 em 332.40 horas
# Navio 56 terminou em 337.07 horas | Tempo de fila: 0.00, Tempo de serviço: 6.39
# Navio 58 chegou no porto em 337.98 horas
# Navio 57 terminou em 339.83 horas | Tempo de fila: 0.00, Tempo de serviço: 7.43
# Navio 58 começou a ser atendido no terminal 14 em 339.83 horas
# Navio 59 chegou no porto em 341.84 horas
# Navio 59 começou a ser atendido no terminal 4 em 341.84 horas
# Navio 58 terminou em 344.36 horas | Tempo de fila: 1.84, Tempo de serviço: 4.53
# Navio 60 chegou no porto em 346.48 horas
# Navio 59 terminou em 347.56 horas | Tempo de fila: 0.00, Tempo de serviço: 5.71
# Navio 60 começou a ser atendido no terminal 4 em 347.56 horas
# Navio 61 chegou no porto em 351.01 horas
# Navio 61 começou a ser atendido no terminal 0 em 351.01 horas
# Navio 60 terminou em 353.53 horas | Tempo de fila: 1.07, Tempo de serviço: 5.97
# Navio 61 terminou em 356.52 horas | Tempo de fila: 0.00, Tempo de serviço: 5.51
# Navio 62 chegou no porto em 356.64 horas
# Navio 62 começou a ser atendido no terminal 8 em 356.64 horas
# Navio 62 terminou em 361.49 horas | Tempo de fila: 0.00, Tempo de serviço: 4.85
# Navio 63 chegou no porto em 366.14 horas
# Navio 63 começou a ser atendido no terminal 8 em 366.14 horas
# Navio 64 chegou no porto em 370.89 horas
# Navio 64 começou a ser atendido no terminal 3 em 370.89 horas
# Navio 65 chegou no porto em 371.31 horas
# Navio 63 terminou em 372.81 horas | Tempo de fila: 0.00, Tempo de serviço: 6.67
# Navio 66 chegou no porto em 376.56 horas
# Navio 64 terminou em 376.73 horas | Tempo de fila: 0.00, Tempo de serviço: 5.84
# Navio 65 começou a ser atendido no terminal 3 em 376.73 horas
# Navio 65 terminou em 382.17 horas | Tempo de fila: 5.42, Tempo de serviço: 5.44
# Navio 66 começou a ser atendido no terminal 3 em 382.17 horas
# Navio 66 terminou em 388.89 horas | Tempo de fila: 5.61, Tempo de serviço: 6.73
# Navio 67 chegou no porto em 407.30 horas
# Navio 67 começou a ser atendido no terminal 5 em 407.30 horas
# Navio 67 terminou em 411.40 horas | Tempo de fila: 0.00, Tempo de serviço: 4.10
# Navio 68 chegou no porto em 416.92 horas
# Navio 68 começou a ser atendido no terminal 7 em 416.92 horas
# Navio 68 terminou em 422.51 horas | Tempo de fila: 0.00, Tempo de serviço: 5.59
# Navio 69 chegou no porto em 424.78 horas
# Navio 69 começou a ser atendido no terminal 2 em 424.78 horas
# Navio 69 terminou em 431.22 horas | Tempo de fila: 0.00, Tempo de serviço: 6.45
# Navio 70 chegou no porto em 435.23 horas
# Navio 70 começou a ser atendido no terminal 1 em 435.23 horas
# Navio 71 chegou no porto em 437.12 horas
# Navio 71 começou a ser atendido no terminal 0 em 437.12 horas
# Navio 72 chegou no porto em 441.24 horas
# Navio 72 começou a ser atendido no terminal 10 em 441.24 horas
# Navio 70 terminou em 442.55 horas | Tempo de fila: 0.00, Tempo de serviço: 7.32
# Navio 71 terminou em 443.04 horas | Tempo de fila: 0.00, Tempo de serviço: 5.91
# Navio 72 terminou em 447.09 horas | Tempo de fila: 0.00, Tempo de serviço: 5.85
# Navio 73 chegou no porto em 447.26 horas
# Navio 73 começou a ser atendido no terminal 9 em 447.26 horas
# Navio 73 terminou em 454.24 horas | Tempo de fila: 0.00, Tempo de serviço: 6.98
# Navio 74 chegou no porto em 458.35 horas
# Navio 74 começou a ser atendido no terminal 9 em 458.35 horas
# Navio 75 chegou no porto em 460.94 horas
# Navio 75 começou a ser atendido no terminal 2 em 460.94 horas
# Navio 76 chegou no porto em 461.02 horas
# Navio 76 começou a ser atendido no terminal 10 em 461.02 horas
# Navio 77 chegou no porto em 462.13 horas
# Navio 74 terminou em 464.28 horas | Tempo de fila: 0.00, Tempo de serviço: 5.93
# Navio 75 terminou em 466.50 horas | Tempo de fila: 0.00, Tempo de serviço: 5.55
# Navio 77 começou a ser atendido no terminal 2 em 466.50 horas
# Navio 76 terminou em 467.05 horas | Tempo de fila: 0.00, Tempo de serviço: 6.04
# Navio 78 chegou no porto em 467.53 horas
# Navio 78 começou a ser atendido no terminal 8 em 467.53 horas
# Navio 79 chegou no porto em 468.51 horas
# Navio 79 começou a ser atendido no terminal 19 em 468.51 horas
# Navio 77 terminou em 472.32 horas | Tempo de fila: 4.37, Tempo de serviço: 5.82
# Navio 80 chegou no porto em 472.39 horas
# Navio 80 começou a ser atendido no terminal 16 em 472.39 horas
# Navio 78 terminou em 474.26 horas | Tempo de fila: 0.00, Tempo de serviço: 6.73
# Navio 79 terminou em 474.40 horas | Tempo de fila: 0.00, Tempo de serviço: 5.89
# Navio 81 chegou no porto em 474.59 horas
# Navio 81 começou a ser atendido no terminal 13 em 474.59 horas
# Navio 82 chegou no porto em 474.80 horas
# Navio 82 começou a ser atendido no terminal 15 em 474.80 horas
# Navio 83 chegou no porto em 475.44 horas
# Navio 83 começou a ser atendido no terminal 3 em 475.44 horas
# Navio 81 terminou em 479.55 horas | Tempo de fila: 0.00, Tempo de serviço: 4.95
# Navio 80 terminou em 479.62 horas | Tempo de fila: 0.00, Tempo de serviço: 7.24
# Navio 83 terminou em 479.98 horas | Tempo de fila: 0.00, Tempo de serviço: 4.54
# Navio 82 terminou em 480.56 horas | Tempo de fila: 0.00, Tempo de serviço: 5.77
# Navio 84 chegou no porto em 482.95 horas
# Navio 84 começou a ser atendido no terminal 8 em 482.95 horas
# Navio 85 chegou no porto em 483.48 horas
# Navio 85 começou a ser atendido no terminal 11 em 483.48 horas
# Navio 85 terminou em 487.74 horas | Tempo de fila: 0.00, Tempo de serviço: 4.25
# Navio 84 terminou em 489.63 horas | Tempo de fila: 0.00, Tempo de serviço: 6.68
# Navio 86 chegou no porto em 491.01 horas
# Navio 86 começou a ser atendido no terminal 14 em 491.01 horas
# Navio 87 chegou no porto em 491.92 horas
# Navio 87 começou a ser atendido no terminal 12 em 491.92 horas
# Navio 86 terminou em 496.71 horas | Tempo de fila: 0.00, Tempo de serviço: 5.70
# Navio 87 terminou em 497.40 horas | Tempo de fila: 0.00, Tempo de serviço: 5.48
# Navio 88 chegou no porto em 497.49 horas
# Navio 88 começou a ser atendido no terminal 14 em 497.49 horas
# Navio 88 terminou em 503.92 horas | Tempo de fila: 0.00, Tempo de serviço: 6.43
# Navio 89 chegou no porto em 508.40 horas
# Navio 89 começou a ser atendido no terminal 5 em 508.40 horas
# Navio 90 chegou no porto em 508.46 horas
# Navio 90 começou a ser atendido no terminal 14 em 508.46 horas
# Navio 89 terminou em 513.79 horas | Tempo de fila: 0.00, Tempo de serviço: 5.39
# Navio 90 terminou em 515.33 horas | Tempo de fila: 0.00, Tempo de serviço: 6.87
# Navio 91 chegou no porto em 515.74 horas
# Navio 91 começou a ser atendido no terminal 17 em 515.74 horas
# Navio 92 chegou no porto em 521.04 horas
# Navio 92 começou a ser atendido no terminal 8 em 521.04 horas
# Navio 91 terminou em 522.12 horas | Tempo de fila: 0.00, Tempo de serviço: 6.38
# Navio 93 chegou no porto em 523.63 horas
# Navio 93 começou a ser atendido no terminal 10 em 523.63 horas
# Navio 92 terminou em 526.60 horas | Tempo de fila: 0.00, Tempo de serviço: 5.56
# Navio 94 chegou no porto em 527.91 horas
# Navio 94 começou a ser atendido no terminal 16 em 527.91 horas
# Navio 95 chegou no porto em 528.61 horas
# Navio 95 começou a ser atendido no terminal 1 em 528.61 horas
# Navio 93 terminou em 528.63 horas | Tempo de fila: 0.00, Tempo de serviço: 5.00
# Navio 94 terminou em 534.63 horas | Tempo de fila: 0.00, Tempo de serviço: 6.72
# Navio 96 chegou no porto em 534.87 horas
# Navio 96 começou a ser atendido no terminal 19 em 534.87 horas
# Navio 95 terminou em 535.89 horas | Tempo de fila: 0.00, Tempo de serviço: 7.28
# Navio 97 chegou no porto em 538.36 horas
# Navio 97 começou a ser atendido no terminal 14 em 538.36 horas
# Navio 96 terminou em 539.35 horas | Tempo de fila: 0.00, Tempo de serviço: 4.48
# Navio 98 chegou no porto em 540.31 horas
# Navio 98 começou a ser atendido no terminal 6 em 540.31 horas
# Navio 99 chegou no porto em 541.35 horas
# Navio 99 começou a ser atendido no terminal 5 em 541.35 horas
# Navio 97 terminou em 545.92 horas | Tempo de fila: 0.00, Tempo de serviço: 7.56
# Navio 98 terminou em 547.34 horas | Tempo de fila: 0.00, Tempo de serviço: 7.03
# Navio 99 terminou em 548.37 horas | Tempo de fila: 0.00, Tempo de serviço: 7.03
# Navio 100 chegou no porto em 549.55 horas
# Navio 100 começou a ser atendido no terminal 1 em 549.55 horas
# Navio 101 chegou no porto em 552.13 horas
# Navio 101 começou a ser atendido no terminal 11 em 552.13 horas
# Navio 102 chegou no porto em 553.20 horas
# Navio 100 terminou em 555.56 horas | Tempo de fila: 0.00, Tempo de serviço: 6.01
# Navio 102 começou a ser atendido no terminal 1 em 555.56 horas
# Navio 101 terminou em 557.17 horas | Tempo de fila: 0.00, Tempo de serviço: 5.04
# Navio 103 chegou no porto em 558.17 horas
# Navio 104 chegou no porto em 558.36 horas
# Navio 104 começou a ser atendido no terminal 14 em 558.36 horas
# Navio 102 terminou em 561.01 horas | Tempo de fila: 2.36, Tempo de serviço: 5.46
# Navio 103 começou a ser atendido no terminal 1 em 561.01 horas
# Navio 105 chegou no porto em 561.48 horas
# Navio 104 terminou em 563.93 horas | Tempo de fila: 0.00, Tempo de serviço: 5.57
# Navio 103 terminou em 567.12 horas | Tempo de fila: 2.85, Tempo de serviço: 6.11
# Navio 105 começou a ser atendido no terminal 1 em 567.12 horas
# Navio 106 chegou no porto em 567.40 horas
# Navio 106 começou a ser atendido no terminal 8 em 567.40 horas
# Navio 107 chegou no porto em 567.68 horas
# Navio 107 começou a ser atendido no terminal 9 em 567.68 horas
# Navio 108 chegou no porto em 570.46 horas
# Navio 108 começou a ser atendido no terminal 17 em 570.46 horas
# Navio 109 chegou no porto em 572.05 horas
# Navio 109 começou a ser atendido no terminal 7 em 572.05 horas
# Navio 110 chegou no porto em 572.23 horas
# Navio 105 terminou em 572.81 horas | Tempo de fila: 5.64, Tempo de serviço: 5.68
# Navio 110 começou a ser atendido no terminal 1 em 572.81 horas
# Navio 106 terminou em 572.87 horas | Tempo de fila: 0.00, Tempo de serviço: 5.47
# Navio 111 chegou no porto em 572.97 horas
# Navio 111 começou a ser atendido no terminal 8 em 572.97 horas
# Navio 107 terminou em 574.00 horas | Tempo de fila: 0.00, Tempo de serviço: 6.32
# Navio 112 chegou no porto em 575.61 horas
# Navio 108 terminou em 575.94 horas | Tempo de fila: 0.00, Tempo de serviço: 5.49
# Navio 109 terminou em 577.36 horas | Tempo de fila: 0.00, Tempo de serviço: 5.31
# Navio 113 chegou no porto em 577.80 horas
# Navio 113 começou a ser atendido no terminal 2 em 577.80 horas
# Navio 111 terminou em 578.90 horas | Tempo de fila: 0.00, Tempo de serviço: 5.93
# Navio 110 terminou em 578.95 horas | Tempo de fila: 0.58, Tempo de serviço: 6.15
# Navio 112 começou a ser atendido no terminal 1 em 578.95 horas
# Navio 113 terminou em 584.16 horas | Tempo de fila: 0.00, Tempo de serviço: 6.36
# Navio 112 terminou em 586.11 horas | Tempo de fila: 3.35, Tempo de serviço: 7.16
# Navio 114 chegou no porto em 586.91 horas
# Navio 114 começou a ser atendido no terminal 8 em 586.91 horas
# Navio 115 chegou no porto em 588.84 horas
# Navio 115 começou a ser atendido no terminal 3 em 588.84 horas
# Navio 114 terminou em 592.55 horas | Tempo de fila: 0.00, Tempo de serviço: 5.64
# Navio 115 terminou em 593.35 horas | Tempo de fila: 0.00, Tempo de serviço: 4.50
# Navio 116 chegou no porto em 594.27 horas
# Navio 116 começou a ser atendido no terminal 1 em 594.27 horas
# Navio 117 chegou no porto em 596.92 horas
# Navio 117 começou a ser atendido no terminal 6 em 596.92 horas
# Navio 118 chegou no porto em 598.57 horas
# Navio 118 começou a ser atendido no terminal 10 em 598.57 horas
# Navio 116 terminou em 600.30 horas | Tempo de fila: 0.00, Tempo de serviço: 6.03
# Navio 117 terminou em 601.27 horas | Tempo de fila: 0.00, Tempo de serviço: 4.35
# Navio 119 chegou no porto em 601.87 horas
# Navio 119 começou a ser atendido no terminal 1 em 601.87 horas
# Navio 118 terminou em 606.14 horas | Tempo de fila: 0.00, Tempo de serviço: 7.58
# Navio 120 chegou no porto em 607.98 horas
# Navio 120 começou a ser atendido no terminal 3 em 607.98 horas
# Navio 119 terminou em 608.62 horas | Tempo de fila: 0.00, Tempo de serviço: 6.75
# Navio 120 terminou em 613.15 horas | Tempo de fila: 0.00, Tempo de serviço: 5.17
# Navio 121 chegou no porto em 625.26 horas
# Navio 121 começou a ser atendido no terminal 9 em 625.26 horas
# Navio 122 chegou no porto em 630.88 horas
# Navio 122 começou a ser atendido no terminal 17 em 630.88 horas
# Navio 121 terminou em 632.41 horas | Tempo de fila: 0.00, Tempo de serviço: 7.15
# Navio 122 terminou em 637.23 horas | Tempo de fila: 0.00, Tempo de serviço: 6.35
# Navio 123 chegou no porto em 640.17 horas
# Navio 123 começou a ser atendido no terminal 2 em 640.17 horas
# Navio 124 chegou no porto em 643.23 horas
# Navio 124 começou a ser atendido no terminal 1 em 643.23 horas
# Navio 123 terminou em 645.27 horas | Tempo de fila: 0.00, Tempo de serviço: 5.09
# Navio 125 chegou no porto em 648.04 horas
# Navio 125 começou a ser atendido no terminal 3 em 648.04 horas
# Navio 124 terminou em 648.07 horas | Tempo de fila: 0.00, Tempo de serviço: 4.84
# Navio 126 chegou no porto em 652.10 horas
# Navio 126 começou a ser atendido no terminal 4 em 652.10 horas
# Navio 125 terminou em 653.38 horas | Tempo de fila: 0.00, Tempo de serviço: 5.34
# Navio 127 chegou no porto em 656.57 horas
# Navio 127 começou a ser atendido no terminal 14 em 656.57 horas
# Navio 126 terminou em 658.76 horas | Tempo de fila: 0.00, Tempo de serviço: 6.66
# Navio 128 chegou no porto em 660.06 horas
# Navio 128 começou a ser atendido no terminal 3 em 660.06 horas
# Navio 127 terminou em 661.06 horas | Tempo de fila: 0.00, Tempo de serviço: 4.49
# Navio 129 chegou no porto em 661.11 horas
# Navio 129 começou a ser atendido no terminal 8 em 661.11 horas
# Navio 128 terminou em 665.25 horas | Tempo de fila: 0.00, Tempo de serviço: 5.18
# Navio 130 chegou no porto em 667.08 horas
# Navio 130 começou a ser atendido no terminal 3 em 667.08 horas
# Navio 129 terminou em 667.22 horas | Tempo de fila: 0.00, Tempo de serviço: 6.10
# Navio 131 chegou no porto em 668.36 horas
# Navio 131 começou a ser atendido no terminal 0 em 668.36 horas
# Navio 132 chegou no porto em 670.43 horas
# Navio 132 começou a ser atendido no terminal 4 em 670.43 horas
# Navio 130 terminou em 673.01 horas | Tempo de fila: 0.00, Tempo de serviço: 5.93
# Navio 131 terminou em 673.05 horas | Tempo de fila: 0.00, Tempo de serviço: 4.69
# Navio 133 chegou no porto em 673.81 horas
# Navio 133 começou a ser atendido no terminal 17 em 673.81 horas
# Navio 132 terminou em 677.43 horas | Tempo de fila: 0.00, Tempo de serviço: 7.00
# Navio 134 chegou no porto em 680.34 horas
# Navio 134 começou a ser atendido no terminal 9 em 680.34 horas
# Navio 135 chegou no porto em 680.52 horas
# Navio 135 começou a ser atendido no terminal 4 em 680.52 horas
# Navio 133 terminou em 680.78 horas | Tempo de fila: 0.00, Tempo de serviço: 6.97
# Navio 136 chegou no porto em 684.16 horas
# Navio 137 chegou no porto em 685.35 horas
# Navio 137 começou a ser atendido no terminal 12 em 685.35 horas
# Navio 134 terminou em 686.48 horas | Tempo de fila: 0.00, Tempo de serviço: 6.14
# Navio 135 terminou em 687.56 horas | Tempo de fila: 0.00, Tempo de serviço: 7.04
# Navio 136 começou a ser atendido no terminal 4 em 687.56 horas
# Navio 138 chegou no porto em 688.64 horas
# Navio 138 começou a ser atendido no terminal 9 em 688.64 horas
# Navio 139 chegou no porto em 689.18 horas
# Navio 137 terminou em 691.08 horas | Tempo de fila: 0.00, Tempo de serviço: 5.73
# Navio 136 terminou em 694.24 horas | Tempo de fila: 3.40, Tempo de serviço: 6.68
# Navio 138 terminou em 695.11 horas | Tempo de fila: 0.00, Tempo de serviço: 6.47
# Navio 139 começou a ser atendido no terminal 9 em 695.11 horas
# Navio 139 terminou em 701.83 horas | Tempo de fila: 5.93, Tempo de serviço: 6.72
# Navio 140 chegou no porto em 708.64 horas
# Navio 140 começou a ser atendido no terminal 3 em 708.64 horas
# Navio 140 terminou em 716.03 horas | Tempo de fila: 0.00, Tempo de serviço: 7.40
#
# Logs dos navios:
# <style type="text/css">
# </style>
# <table id="T_dae38">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dae38_level0_col0" class="col_heading level0 col0" >ID Navio</th>
#       <th id="T_dae38_level0_col1" class="col_heading level0 col1" >Terminal</th>
#       <th id="T_dae38_level0_col2" class="col_heading level0 col2" >Chegada</th>
#       <th id="T_dae38_level0_col3" class="col_heading level0 col3" >Início Serviço</th>
#       <th id="T_dae38_level0_col4" class="col_heading level0 col4" >Fila (h)</th>
#       <th id="T_dae38_level0_col5" class="col_heading level0 col5" >Duração Serviço</th>
#       <th id="T_dae38_level0_col6" class="col_heading level0 col6" >Término</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dae38_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dae38_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_dae38_row0_col1" class="data row0 col1" >13</td>
#       <td id="T_dae38_row0_col2" class="data row0 col2" >2.94</td>
#       <td id="T_dae38_row0_col3" class="data row0 col3" >2.94</td>
#       <td id="T_dae38_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_dae38_row0_col5" class="data row0 col5" >5.10</td>
#       <td id="T_dae38_row0_col6" class="data row0 col6" >8.04</td>
#     </tr>
#     <tr>
#       <th id="T_dae38_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dae38_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_dae38_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_dae38_row1_col2" class="data row1 col2" >15.25</td>
#       <td id="T_dae38_row1_col3" class="data row1 col3" >15.25</td>
#       <td id="T_dae38_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_dae38_row1_col5" class="data row1 col5" >4.29</td>
#       <td id="T_dae38_row1_col6" class="data row1 col6" >19.54</td>
#     </tr>
#     <tr>
#       <th id="T_dae38_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dae38_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_dae38_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_dae38_row2_col2" class="data row2 col2" >14.61</td>
#       <td id="T_dae38_row2_col3" class="data row2 col3" >14.61</td>
#       <td id="T_dae38_row2_col4" class="data row2 col4" >0.00</td>
#       <td id="T_dae38_row2_col5" class="data row2 col5" >5.43</td>
#       <td id="T_dae38_row2_col6" class="data row2 col6" >20.04</td>
#     </tr>
#     <tr>
#       <th id="T_dae38_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dae38_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_dae38_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_dae38_row3_col2" class="data row3 col2" >40.97</td>
#       <td id="T_dae38_row3_col3" class="data row3 col3" >40.97</td>
#       <td id="T_dae38_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_dae38_row3_col5" class="data row3 col5" >5.23</td>
#       <td id="T_dae38_row3_col6" class="data row3 col6" >46.21</td>
#     </tr>
#     <tr>
#       <th id="T_dae38_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dae38_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_dae38_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_dae38_row4_col2" class="data row4 col2" >48.46</td>
#       <td id="T_dae38_row4_col3" class="data row4 col3" >48.46</td>
#       <td id="T_dae38_row4_col4" class="data row4 col4" >0.00</td>
#       <td id="T_dae38_row4_col5" class="data row4 col5" >4.73</td>
#       <td id="T_dae38_row4_col6" class="data row4 col6" >53.19</td>
#     </tr>
#     <tr>
#       <th id="T_dae38_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dae38_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_dae38_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_dae38_row5_col2" class="data row5 col2" >48.46</td>
#       <td id="T_dae38_row5_col3" class="data row5 col3" >48.46</td>
#       <td id="T_dae38_row5_col4" class="data row5 col4" >0.00</td>
#       <td id="T_dae38_row5_col5" class="data row5 col5" >5.03</td>
#       <td id="T_dae38_row5_col6" class="data row5 col6" >53.48</td>
#     </tr>
#     <tr>
#       <th id="T_dae38_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dae38_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_dae38_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_dae38_row6_col2" class="data row6 col2" >52.56</td>
#       <td id="T_dae38_row6_col3" class="data row6 col3" >52.56</td>
#       <td id="T_dae38_row6_col4" class="data row6 col4" >0.00</td>
#       <td id="T_dae38_row6_col5" class="data row6 col5" >5.87</td>
#       <td id="T_dae38_row6_col6" class="data row6 col6" >58.43</td>
#     </tr>
#     <tr>
#       <th id="T_dae38_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dae38_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_dae38_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_dae38_row7_col2" class="data row7 col2" >55.58</td>
#       <td id="T_dae38_row7_col3" class="data row7 col3" >55.58</td>
#       <td id="T_dae38_row7_col4" class="data row7 col4" >0.00</td>
#       <td id="T_dae38_row7_col5" class="data row7 col5" >5.34</td>
#       <td id="T_dae38_row7_col6" class="data row7 col6" >60.92</td>
#     </tr>
#     <tr>
#       <th id="T_dae38_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dae38_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_dae38_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_dae38_row8_col2" class="data row8 col2" >63.49</td>
#       <td id="T_dae38_row8_col3" class="data row8 col3" >63.49</td>
#       <td id="T_dae38_row8_col4" class="data row8 col4" >0.00</td>
#       <td id="T_dae38_row8_col5" class="data row8 col5" >5.76</td>
#       <td id="T_dae38_row8_col6" class="data row8 col6" >69.25</td>
#     </tr>
#     <tr>
#       <th id="T_dae38_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dae38_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_dae38_row9_col1" class="data row9 col1" >3</td>
#       <td id="T_dae38_row9_col2" class="data row9 col2" >72.76</td>
#       <td id="T_dae38_row9_col3" class="data row9 col3" >72.76</td>
#       <td id="T_dae38_row9_col4" class="data row9 col4" >0.00</td>
#       <td id="T_dae38_row9_col5" class="data row9 col5" >6.65</td>
#       <td id="T_dae38_row9_col6" class="data row9 col6" >79.42</td>
#     </tr>
#   </tbody>
# </table>
# Logs dos terminais:
# <style type="text/css">
# </style>
# <table id="T_9b186">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b186_level0_col0" class="col_heading level0 col0" >Terminal</th>
#       <th id="T_9b186_level0_col1" class="col_heading level0 col1" >Tempo Ocioso (h)</th>
#       <th id="T_9b186_level0_col2" class="col_heading level0 col2" >Tempo Total (h)</th>
#       <th id="T_9b186_level0_col3" class="col_heading level0 col3" >Ocupação (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b186_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b186_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9b186_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_9b186_row0_col2" class="data row0 col2" >720</td>
#       <td id="T_9b186_row0_col3" class="data row0 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9b186_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_9b186_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_9b186_row1_col2" class="data row1 col2" >720</td>
#       <td id="T_9b186_row1_col3" class="data row1 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9b186_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_9b186_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_9b186_row2_col2" class="data row2 col2" >720</td>
#       <td id="T_9b186_row2_col3" class="data row2 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9b186_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_9b186_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_9b186_row3_col2" class="data row3 col2" >720</td>
#       <td id="T_9b186_row3_col3" class="data row3 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9b186_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_9b186_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_9b186_row4_col2" class="data row4 col2" >720</td>
#       <td id="T_9b186_row4_col3" class="data row4 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9b186_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_9b186_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_9b186_row5_col2" class="data row5 col2" >720</td>
#       <td id="T_9b186_row5_col3" class="data row5 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9b186_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_9b186_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_9b186_row6_col2" class="data row6 col2" >720</td>
#       <td id="T_9b186_row6_col3" class="data row6 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9b186_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_9b186_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_9b186_row7_col2" class="data row7 col2" >720</td>
#       <td id="T_9b186_row7_col3" class="data row7 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9b186_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_9b186_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_9b186_row8_col2" class="data row8 col2" >720</td>
#       <td id="T_9b186_row8_col3" class="data row8 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9b186_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_9b186_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_9b186_row9_col2" class="data row9 col2" >720</td>
#       <td id="T_9b186_row9_col3" class="data row9 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9b186_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_9b186_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_9b186_row10_col2" class="data row10 col2" >720</td>
#       <td id="T_9b186_row10_col3" class="data row10 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9b186_row11_col0" class="data row11 col0" >11</td>
#       <td id="T_9b186_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_9b186_row11_col2" class="data row11 col2" >720</td>
#       <td id="T_9b186_row11_col3" class="data row11 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9b186_row12_col0" class="data row12 col0" >12</td>
#       <td id="T_9b186_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_9b186_row12_col2" class="data row12 col2" >720</td>
#       <td id="T_9b186_row12_col3" class="data row12 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9b186_row13_col0" class="data row13 col0" >13</td>
#       <td id="T_9b186_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_9b186_row13_col2" class="data row13 col2" >720</td>
#       <td id="T_9b186_row13_col3" class="data row13 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9b186_row14_col0" class="data row14 col0" >14</td>
#       <td id="T_9b186_row14_col1" class="data row14 col1" >0</td>
#       <td id="T_9b186_row14_col2" class="data row14 col2" >720</td>
#       <td id="T_9b186_row14_col3" class="data row14 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9b186_row15_col0" class="data row15 col0" >15</td>
#       <td id="T_9b186_row15_col1" class="data row15 col1" >0</td>
#       <td id="T_9b186_row15_col2" class="data row15 col2" >720</td>
#       <td id="T_9b186_row15_col3" class="data row15 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9b186_row16_col0" class="data row16 col0" >16</td>
#       <td id="T_9b186_row16_col1" class="data row16 col1" >0</td>
#       <td id="T_9b186_row16_col2" class="data row16 col2" >720</td>
#       <td id="T_9b186_row16_col3" class="data row16 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9b186_row17_col0" class="data row17 col0" >17</td>
#       <td id="T_9b186_row17_col1" class="data row17 col1" >0</td>
#       <td id="T_9b186_row17_col2" class="data row17 col2" >720</td>
#       <td id="T_9b186_row17_col3" class="data row17 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9b186_row18_col0" class="data row18 col0" >18</td>
#       <td id="T_9b186_row18_col1" class="data row18 col1" >0</td>
#       <td id="T_9b186_row18_col2" class="data row18 col2" >720</td>
#       <td id="T_9b186_row18_col3" class="data row18 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b186_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9b186_row19_col0" class="data row19 col0" >19</td>
#       <td id="T_9b186_row19_col1" class="data row19 col1" >0</td>
#       <td id="T_9b186_row19_col2" class="data row19 col2" >720</td>
#       <td id="T_9b186_row19_col3" class="data row19 col3" >100.00</td>
#     </tr>
#   </tbody>
# </table>
