# %%
import simpy
import random
import numpy as np
import pandas as pd
from datetime import timedelta

# Configuração da simulação
NUM_TERMINALS = 20
SHIP_ARRIVAL_RATE = 5  # navios por dia
SIM_DURATION = 30  # dias de simulação

# Distribuição de destino dos navios (exemplo: 50% dos navios vão para os 5 primeiros terminais)
DESTINATION_PROBS = [0.08] * 5 + [0.06] * 5 + [0.04] * 5 + [0.02] * 5

# Parâmetros do tempo de serviço por terminal (distribuição triangular)
SERVICE_TIMES = {i: (4, 8, 6) for i in range(NUM_TERMINALS)}  # (min, max, modo)

# Listas para armazenar resultados
ship_log = []
terminal_log = []

class Porto:
    def __init__(self, env):
        self.env = env
        self.terminals = {i: simpy.Resource(env, capacity=1) for i in range(NUM_TERMINALS)}
        self.terminal_status = {i: {'start': None, 'idle_time': 0} for i in range(NUM_TERMINALS)}

    def service(self, ship_id,  arrival_time, terminal_id, duration_params):
        with self.terminals[terminal_id].request() as req:
            yield req  # Aguarda o terminal ficar disponível

            # Registra início do uso do terminal
            if self.terminal_status[terminal_id]['start'] is None:
                self.terminal_status[terminal_id]['start'] = self.env.now
            else:
                idle_time = self.env.now - self.terminal_status[terminal_id]['start']
                self.terminal_status[terminal_id]['idle_time'] += idle_time

            start_time = self.env.now
            print(f'Navio {ship_id} começou a ser atendido no terminal {terminal_id} em {start_time:.2f} horas')

            # Gera duração do serviço
            duration = random.triangular(*duration_params)
            yield self.env.timeout(duration)

            end_time = self.env.now
            print(f'Navio {ship_id} terminou em {end_time:.2f} horas | Tempo de fila: {(start_time - arrival_time):.2f}, Tempo de serviço: {duration:.2f}')

            # Armazena resultados
            ship_log.append({
                'ID Navio': ship_id,
                'Terminal': terminal_id,
                'Chegada': arrival_time,
                'Início Serviço': start_time,
                'Fila (h)': start_time - arrival_time,
                'Duração Serviço': duration,
                'Término': end_time
            })

            # Atualiza status do terminal
            self.terminal_status[terminal_id]['start'] = None

def ship_generator(env, porto):
    ship_id = 0
    while True:
        # Intervalo entre chegadas (Poisson)
        interarrival_time = random.expovariate(SHIP_ARRIVAL_RATE / 24)  # convertendo para horas
        yield env.timeout(interarrival_time)

        ship_id += 1
        destination = np.random.choice(range(NUM_TERMINALS), p=DESTINATION_PROBS)
        duration_params = SERVICE_TIMES[destination]

        arrival_time = env.now
        print(f'Navio {ship_id} chegou no porto em {arrival_time:.2f} horas')

            
        env.process(porto.service(ship_id, arrival_time, destination, duration_params))

def run_simulation():
    env = simpy.Environment()
    porto = Porto(env)
    env.process(ship_generator(env, porto))
    env.run(until=SIM_DURATION * 24)  # Converte dias para horas

    # DataFrame com logs dos navios
    df_ships = pd.DataFrame(ship_log)
    df_terminals = []

    for term_id, log in porto.terminal_status.items():
        df_terminals.append({
            'Terminal': term_id,
            'Tempo Ocioso (h)': log['idle_time'],
            'Tempo Total (h)': SIM_DURATION * 24,
            'Ocupação (%)': ((SIM_DURATION * 24 - log['idle_time']) / (SIM_DURATION * 24)) * 100
        })

    df_terminals = pd.DataFrame(df_terminals)

    return df_ships, df_terminals

# Roda a simulação
df_ships, df_terminals = run_simulation()

# Mostra resultados
print("\nLogs dos navios:")
display(df_ships.head(10).style.format(precision=2))

print("\nLogs dos terminais:")
display(df_terminals.style.format(precision=2))
# Out:
# Navio 1 começou a ser atendido no terminal 5 em 2.50 horas
# Navio 1 terminou em 9.74 horas | Tempo de fila: 0.00, Tempo de serviço: 7.24
# Navio 2 começou a ser atendido no terminal 2 em 12.90 horas
# Navio 2 terminou em 18.58 horas | Tempo de fila: 0.00, Tempo de serviço: 5.68
# Navio 3 começou a ser atendido no terminal 2 em 24.20 horas
# Navio 4 começou a ser atendido no terminal 0 em 26.31 horas
# Navio 3 terminou em 30.44 horas | Tempo de fila: 0.00, Tempo de serviço: 6.24
# Navio 4 terminou em 31.59 horas | Tempo de fila: 0.00, Tempo de serviço: 5.28
# Navio 5 começou a ser atendido no terminal 9 em 33.01 horas
# Navio 5 terminou em 39.31 horas | Tempo de fila: 0.00, Tempo de serviço: 6.30
# Navio 6 começou a ser atendido no terminal 19 em 47.64 horas
# Navio 7 começou a ser atendido no terminal 0 em 50.16 horas
# Navio 6 terminou em 52.39 horas | Tempo de fila: 0.00, Tempo de serviço: 4.75
# Navio 8 começou a ser atendido no terminal 6 em 52.47 horas
# Navio 9 começou a ser atendido no terminal 11 em 53.44 horas
# Navio 7 terminou em 56.41 horas | Tempo de fila: 0.00, Tempo de serviço: 6.25
# Navio 8 terminou em 57.64 horas | Tempo de fila: 0.00, Tempo de serviço: 5.17
# Navio 10 começou a ser atendido no terminal 0 em 59.04 horas
# Navio 9 terminou em 60.94 horas | Tempo de fila: 0.00, Tempo de serviço: 7.49
# Navio 10 terminou em 64.45 horas | Tempo de fila: 0.00, Tempo de serviço: 5.41
# Navio 11 começou a ser atendido no terminal 0 em 67.28 horas
# Navio 11 terminou em 72.85 horas | Tempo de fila: 0.00, Tempo de serviço: 5.57
# Navio 12 começou a ser atendido no terminal 4 em 78.39 horas
# Navio 12 terminou em 83.31 horas | Tempo de fila: 0.00, Tempo de serviço: 4.92
# Navio 13 começou a ser atendido no terminal 3 em 90.35 horas
# Navio 14 começou a ser atendido no terminal 0 em 94.33 horas
# Navio 13 terminou em 96.19 horas | Tempo de fila: 0.00, Tempo de serviço: 5.83
# Navio 14 terminou em 101.84 horas | Tempo de fila: 0.00, Tempo de serviço: 7.51
# Navio 15 começou a ser atendido no terminal 6 em 107.84 horas
# Navio 15 terminou em 112.94 horas | Tempo de fila: 0.00, Tempo de serviço: 5.09
# Navio 16 começou a ser atendido no terminal 11 em 115.20 horas
# Navio 17 começou a ser atendido no terminal 17 em 119.75 horas
# Navio 16 terminou em 120.16 horas | Tempo de fila: 0.00, Tempo de serviço: 4.96
# Navio 18 começou a ser atendido no terminal 0 em 120.78 horas
# Navio 19 começou a ser atendido no terminal 9 em 121.44 horas
# Navio 17 terminou em 124.87 horas | Tempo de fila: 0.00, Tempo de serviço: 5.12
# Navio 18 terminou em 125.52 horas | Tempo de fila: 0.00, Tempo de serviço: 4.74
# Navio 19 terminou em 126.70 horas | Tempo de fila: 0.00, Tempo de serviço: 5.25
# Navio 20 começou a ser atendido no terminal 5 em 132.24 horas
# Navio 21 começou a ser atendido no terminal 11 em 135.63 horas
# Navio 22 começou a ser atendido no terminal 8 em 137.82 horas
# Navio 20 terminou em 138.44 horas | Tempo de fila: 0.00, Tempo de serviço: 6.20
# Navio 21 terminou em 140.60 horas | Tempo de fila: 0.00, Tempo de serviço: 4.98
# Navio 22 terminou em 143.59 horas | Tempo de fila: 0.00, Tempo de serviço: 5.77
# Navio 23 começou a ser atendido no terminal 1 em 144.47 horas
# Navio 24 começou a ser atendido no terminal 0 em 146.97 horas
# Navio 23 terminou em 149.84 horas | Tempo de fila: 0.00, Tempo de serviço: 5.37
# Navio 24 terminou em 153.75 horas | Tempo de fila: 0.00, Tempo de serviço: 6.78
# Navio 25 começou a ser atendido no terminal 13 em 167.50 horas
# Navio 25 terminou em 171.98 horas | Tempo de fila: 0.00, Tempo de serviço: 4.48
# Navio 26 começou a ser atendido no terminal 13 em 176.63 horas
# Navio 27 começou a ser atendido no terminal 2 em 178.98 horas
# Navio 26 terminou em 181.66 horas | Tempo de fila: 0.00, Tempo de serviço: 5.03
# Navio 27 terminou em 184.85 horas | Tempo de fila: 0.00, Tempo de serviço: 5.88
# Navio 28 começou a ser atendido no terminal 6 em 185.06 horas
# Navio 29 começou a ser atendido no terminal 2 em 187.87 horas
# Navio 30 começou a ser atendido no terminal 7 em 188.63 horas
# Navio 28 terminou em 190.18 horas | Tempo de fila: 0.00, Tempo de serviço: 5.11
# Navio 29 terminou em 193.45 horas | Tempo de fila: 0.00, Tempo de serviço: 5.58
# Navio 30 terminou em 193.65 horas | Tempo de fila: 0.00, Tempo de serviço: 5.02
# Navio 31 começou a ser atendido no terminal 3 em 195.56 horas
# Navio 32 começou a ser atendido no terminal 4 em 197.93 horas
# Navio 31 terminou em 200.92 horas | Tempo de fila: 0.00, Tempo de serviço: 5.36
# Navio 33 começou a ser atendido no terminal 5 em 202.04 horas
# Navio 32 terminou em 204.43 horas | Tempo de fila: 0.00, Tempo de serviço: 6.50
# Navio 34 começou a ser atendido no terminal 3 em 206.60 horas
# Navio 33 terminou em 207.95 horas | Tempo de fila: 0.00, Tempo de serviço: 5.91
# Navio 34 terminou em 212.84 horas | Tempo de fila: 0.00, Tempo de serviço: 6.24
# Navio 35 começou a ser atendido no terminal 5 em 213.37 horas
# Navio 36 começou a ser atendido no terminal 0 em 219.74 horas
# Navio 35 terminou em 219.79 horas | Tempo de fila: 0.00, Tempo de serviço: 6.42
# Navio 37 começou a ser atendido no terminal 12 em 221.83 horas
# Navio 36 terminou em 224.61 horas | Tempo de fila: 0.00, Tempo de serviço: 4.87
# Navio 37 terminou em 226.77 horas | Tempo de fila: 0.00, Tempo de serviço: 4.94
# Navio 38 começou a ser atendido no terminal 4 em 230.87 horas
# Navio 38 terminou em 236.51 horas | Tempo de fila: 0.00, Tempo de serviço: 5.65
# Navio 39 começou a ser atendido no terminal 10 em 238.09 horas
# Navio 39 terminou em 243.81 horas | Tempo de fila: 0.00, Tempo de serviço: 5.72
# Navio 40 começou a ser atendido no terminal 9 em 251.30 horas
# Navio 41 começou a ser atendido no terminal 1 em 255.69 horas
# Navio 40 terminou em 257.39 horas | Tempo de fila: 0.00, Tempo de serviço: 6.09
# Navio 42 começou a ser atendido no terminal 15 em 259.94 horas
# Navio 41 terminou em 261.81 horas | Tempo de fila: 0.00, Tempo de serviço: 6.12
# Navio 43 começou a ser atendido no terminal 2 em 264.31 horas
# Navio 44 começou a ser atendido no terminal 17 em 265.06 horas
# Navio 42 terminou em 266.13 horas | Tempo de fila: 0.00, Tempo de serviço: 6.19
# Navio 44 terminou em 269.92 horas | Tempo de fila: 0.00, Tempo de serviço: 4.86
# Navio 43 terminou em 270.24 horas | Tempo de fila: 0.00, Tempo de serviço: 5.93
# Navio 45 começou a ser atendido no terminal 2 em 270.24 horas
# Navio 45 terminou em 276.22 horas | Tempo de fila: 4.64, Tempo de serviço: 5.98
# Navio 46 começou a ser atendido no terminal 2 em 276.22 horas
# Navio 47 começou a ser atendido no terminal 12 em 279.86 horas
# Navio 46 terminou em 282.47 horas | Tempo de fila: 3.93, Tempo de serviço: 6.25
# Navio 48 começou a ser atendido no terminal 3 em 285.34 horas
# Navio 47 terminou em 286.39 horas | Tempo de fila: 0.00, Tempo de serviço: 6.54
# Navio 49 começou a ser atendido no terminal 1 em 288.92 horas
# Navio 48 terminou em 290.75 horas | Tempo de fila: 0.00, Tempo de serviço: 5.42
# Navio 49 terminou em 295.16 horas | Tempo de fila: 0.00, Tempo de serviço: 6.25
# Navio 50 começou a ser atendido no terminal 10 em 300.37 horas
# Navio 51 começou a ser atendido no terminal 9 em 303.14 horas
# Navio 52 começou a ser atendido no terminal 16 em 303.95 horas
# Navio 50 terminou em 305.27 horas | Tempo de fila: 0.00, Tempo de serviço: 4.90
# Navio 51 terminou em 308.32 horas | Tempo de fila: 0.00, Tempo de serviço: 5.18
# Navio 52 terminou em 308.79 horas | Tempo de fila: 0.00, Tempo de serviço: 4.85
# Navio 53 começou a ser atendido no terminal 7 em 317.68 horas
# Navio 53 terminou em 322.71 horas | Tempo de fila: 0.00, Tempo de serviço: 5.03
# Navio 54 começou a ser atendido no terminal 11 em 325.78 horas
# Navio 55 começou a ser atendido no terminal 1 em 331.08 horas
# Navio 54 terminou em 332.82 horas | Tempo de fila: 0.00, Tempo de serviço: 7.04
# Navio 56 começou a ser atendido no terminal 6 em 334.02 horas
# Navio 55 terminou em 336.12 horas | Tempo de fila: 0.00, Tempo de serviço: 5.04
# Navio 56 terminou em 339.75 horas | Tempo de fila: 0.00, Tempo de serviço: 5.74
# Navio 57 começou a ser atendido no terminal 6 em 342.59 horas
# Navio 58 começou a ser atendido no terminal 5 em 343.91 horas
# Navio 57 terminou em 348.47 horas | Tempo de fila: 0.00, Tempo de serviço: 5.88
# Navio 59 começou a ser atendido no terminal 6 em 348.47 horas
# Navio 60 começou a ser atendido no terminal 12 em 348.82 horas
# Navio 58 terminou em 349.12 horas | Tempo de fila: 0.00, Tempo de serviço: 5.22
# Navio 61 começou a ser atendido no terminal 9 em 352.69 horas
# Navio 60 terminou em 353.86 horas | Tempo de fila: 0.00, Tempo de serviço: 5.03
# Navio 59 terminou em 353.86 horas | Tempo de fila: 3.41, Tempo de serviço: 5.39
# Navio 62 começou a ser atendido no terminal 3 em 357.99 horas
# Navio 61 terminou em 359.52 horas | Tempo de fila: 0.00, Tempo de serviço: 6.83
# Navio 62 terminou em 364.33 horas | Tempo de fila: 0.00, Tempo de serviço: 6.34
# Navio 63 começou a ser atendido no terminal 9 em 369.96 horas
# Navio 64 começou a ser atendido no terminal 3 em 370.47 horas
# Navio 63 terminou em 374.76 horas | Tempo de fila: 0.00, Tempo de serviço: 4.80
# Navio 65 começou a ser atendido no terminal 5 em 375.42 horas
# Navio 64 terminou em 375.56 horas | Tempo de fila: 0.00, Tempo de serviço: 5.09
# Navio 66 começou a ser atendido no terminal 12 em 376.41 horas
# Navio 67 começou a ser atendido no terminal 13 em 378.27 horas
# Navio 65 terminou em 380.25 horas | Tempo de fila: 0.00, Tempo de serviço: 4.83
# Navio 66 terminou em 381.98 horas | Tempo de fila: 0.00, Tempo de serviço: 5.58
# Navio 67 terminou em 383.43 horas | Tempo de fila: 0.00, Tempo de serviço: 5.16
# Navio 68 começou a ser atendido no terminal 13 em 383.43 horas
# Navio 68 terminou em 389.43 horas | Tempo de fila: 1.66, Tempo de serviço: 5.99
# Navio 69 começou a ser atendido no terminal 13 em 389.43 horas
# Navio 71 começou a ser atendido no terminal 5 em 395.07 horas
# Navio 69 terminou em 395.74 horas | Tempo de fila: 5.61, Tempo de serviço: 6.31
# Navio 70 começou a ser atendido no terminal 13 em 395.74 horas
# Navio 72 começou a ser atendido no terminal 0 em 396.75 horas
# Navio 70 terminou em 400.52 horas | Tempo de fila: 11.15, Tempo de serviço: 4.79
# Navio 71 terminou em 401.71 horas | Tempo de fila: 0.00, Tempo de serviço: 6.64
# Navio 72 terminou em 403.39 horas | Tempo de fila: 0.00, Tempo de serviço: 6.64
# Navio 73 começou a ser atendido no terminal 14 em 404.03 horas
# Navio 73 terminou em 409.99 horas | Tempo de fila: 0.00, Tempo de serviço: 5.95
# Navio 74 começou a ser atendido no terminal 6 em 416.74 horas
# Navio 74 terminou em 422.54 horas | Tempo de fila: 0.00, Tempo de serviço: 5.80
# Navio 75 começou a ser atendido no terminal 19 em 424.50 horas
# Navio 75 terminou em 429.37 horas | Tempo de fila: 0.00, Tempo de serviço: 4.87
# Navio 76 começou a ser atendido no terminal 6 em 432.16 horas
# Navio 77 começou a ser atendido no terminal 0 em 437.15 horas
# Navio 76 terminou em 438.51 horas | Tempo de fila: 0.00, Tempo de serviço: 6.35
# Navio 78 começou a ser atendido no terminal 8 em 440.97 horas
# Navio 77 terminou em 443.16 horas | Tempo de fila: 0.00, Tempo de serviço: 6.01
# Navio 78 terminou em 447.88 horas | Tempo de fila: 0.00, Tempo de serviço: 6.90
# Navio 79 começou a ser atendido no terminal 14 em 448.98 horas
# Navio 80 começou a ser atendido no terminal 1 em 450.92 horas
# Navio 79 terminou em 455.81 horas | Tempo de fila: 0.00, Tempo de serviço: 6.83
# Navio 80 terminou em 456.51 horas | Tempo de fila: 0.00, Tempo de serviço: 5.60
# Navio 81 começou a ser atendido no terminal 14 em 456.58 horas
# Navio 82 começou a ser atendido no terminal 9 em 459.69 horas
# Navio 81 terminou em 462.77 horas | Tempo de fila: 0.00, Tempo de serviço: 6.19
# Navio 83 começou a ser atendido no terminal 10 em 463.20 horas
# Navio 82 terminou em 466.76 horas | Tempo de fila: 0.00, Tempo de serviço: 7.07
# Navio 83 terminou em 467.78 horas | Tempo de fila: 0.00, Tempo de serviço: 4.58
# Navio 84 começou a ser atendido no terminal 5 em 468.27 horas
# Navio 85 começou a ser atendido no terminal 9 em 469.76 horas
# Navio 86 começou a ser atendido no terminal 4 em 470.72 horas
# Navio 84 terminou em 474.45 horas | Tempo de fila: 0.00, Tempo de serviço: 6.18
# Navio 87 começou a ser atendido no terminal 14 em 475.73 horas
# Navio 85 terminou em 476.13 horas | Tempo de fila: 0.00, Tempo de serviço: 6.38
# Navio 86 terminou em 477.71 horas | Tempo de fila: 0.00, Tempo de serviço: 6.98
# Navio 88 começou a ser atendido no terminal 6 em 477.79 horas
# Navio 87 terminou em 480.72 horas | Tempo de fila: 0.00, Tempo de serviço: 4.99
# Navio 88 terminou em 483.43 horas | Tempo de fila: 0.00, Tempo de serviço: 5.64
# Navio 89 começou a ser atendido no terminal 0 em 484.83 horas
# Navio 90 começou a ser atendido no terminal 1 em 486.70 horas
# Navio 91 começou a ser atendido no terminal 12 em 487.09 horas
# Navio 89 terminou em 491.29 horas | Tempo de fila: 0.00, Tempo de serviço: 6.47
# Navio 90 terminou em 492.75 horas | Tempo de fila: 0.00, Tempo de serviço: 6.05
# Navio 91 terminou em 493.24 horas | Tempo de fila: 0.00, Tempo de serviço: 6.16
# Navio 92 começou a ser atendido no terminal 0 em 496.63 horas
# Navio 92 terminou em 501.63 horas | Tempo de fila: 0.00, Tempo de serviço: 5.00
# Navio 93 começou a ser atendido no terminal 4 em 506.31 horas
# Navio 94 começou a ser atendido no terminal 1 em 507.91 horas
# Navio 93 terminou em 512.44 horas | Tempo de fila: 0.00, Tempo de serviço: 6.13
# Navio 94 terminou em 514.31 horas | Tempo de fila: 0.00, Tempo de serviço: 6.40
# Navio 95 começou a ser atendido no terminal 0 em 527.69 horas
# Navio 95 terminou em 534.30 horas | Tempo de fila: 0.00, Tempo de serviço: 6.61
# Navio 96 começou a ser atendido no terminal 2 em 536.88 horas
# Navio 97 começou a ser atendido no terminal 0 em 541.35 horas
# Navio 98 começou a ser atendido no terminal 3 em 541.87 horas
# Navio 96 terminou em 541.98 horas | Tempo de fila: 0.00, Tempo de serviço: 5.11
# Navio 99 começou a ser atendido no terminal 10 em 543.94 horas
# Navio 100 começou a ser atendido no terminal 7 em 544.05 horas
# Navio 101 começou a ser atendido no terminal 2 em 545.36 horas
# Navio 102 começou a ser atendido no terminal 8 em 545.94 horas
# Navio 97 terminou em 547.74 horas | Tempo de fila: 0.00, Tempo de serviço: 6.39
# Navio 98 terminou em 548.01 horas | Tempo de fila: 0.00, Tempo de serviço: 6.13
# Navio 103 começou a ser atendido no terminal 4 em 548.41 horas
# Navio 100 terminou em 549.17 horas | Tempo de fila: 0.00, Tempo de serviço: 5.13
# Navio 99 terminou em 549.35 horas | Tempo de fila: 0.00, Tempo de serviço: 5.41
# Navio 104 começou a ser atendido no terminal 3 em 549.60 horas
# Navio 102 terminou em 550.50 horas | Tempo de fila: 0.00, Tempo de serviço: 4.56
# Navio 101 terminou em 550.91 horas | Tempo de fila: 0.00, Tempo de serviço: 5.55
# Navio 105 começou a ser atendido no terminal 16 em 552.21 horas
# Navio 103 terminou em 555.14 horas | Tempo de fila: 0.00, Tempo de serviço: 6.74
# Navio 104 terminou em 555.78 horas | Tempo de fila: 0.00, Tempo de serviço: 6.17
# Navio 106 começou a ser atendido no terminal 1 em 556.36 horas
# Navio 105 terminou em 557.97 horas | Tempo de fila: 0.00, Tempo de serviço: 5.77
# Navio 107 começou a ser atendido no terminal 9 em 558.65 horas
# Navio 106 terminou em 563.10 horas | Tempo de fila: 0.00, Tempo de serviço: 6.74
# Navio 107 terminou em 565.05 horas | Tempo de fila: 0.00, Tempo de serviço: 6.40
# Navio 108 começou a ser atendido no terminal 18 em 571.88 horas
# Navio 108 terminou em 576.95 horas | Tempo de fila: 0.00, Tempo de serviço: 5.08
# Navio 109 começou a ser atendido no terminal 7 em 578.95 horas
# Navio 110 começou a ser atendido no terminal 1 em 583.85 horas
# Navio 111 começou a ser atendido no terminal 9 em 584.39 horas
# Navio 112 começou a ser atendido no terminal 4 em 584.55 horas
# Navio 109 terminou em 585.07 horas | Tempo de fila: 0.00, Tempo de serviço: 6.11
# Navio 111 terminou em 588.94 horas | Tempo de fila: 0.00, Tempo de serviço: 4.55
# Navio 110 terminou em 590.25 horas | Tempo de fila: 0.00, Tempo de serviço: 6.40
# Navio 112 terminou em 590.76 horas | Tempo de fila: 0.00, Tempo de serviço: 6.21
# Navio 113 começou a ser atendido no terminal 8 em 595.81 horas
# Navio 114 começou a ser atendido no terminal 13 em 600.36 horas
# Navio 113 terminou em 601.96 horas | Tempo de fila: 0.00, Tempo de serviço: 6.15
# Navio 114 terminou em 605.46 horas | Tempo de fila: 0.00, Tempo de serviço: 5.09
# Navio 115 começou a ser atendido no terminal 12 em 607.28 horas
# Navio 115 terminou em 613.05 horas | Tempo de fila: 0.00, Tempo de serviço: 5.77
# Navio 116 começou a ser atendido no terminal 16 em 620.22 horas
# Navio 116 terminou em 624.35 horas | Tempo de fila: 0.00, Tempo de serviço: 4.14
# Navio 117 começou a ser atendido no terminal 9 em 630.67 horas
# Navio 118 começou a ser atendido no terminal 4 em 631.41 horas
# Navio 117 terminou em 636.32 horas | Tempo de fila: 0.00, Tempo de serviço: 5.65
# Navio 118 terminou em 638.23 horas | Tempo de fila: 0.00, Tempo de serviço: 6.81
# Navio 119 começou a ser atendido no terminal 1 em 643.06 horas
# Navio 120 começou a ser atendido no terminal 2 em 643.88 horas
# Navio 122 começou a ser atendido no terminal 5 em 648.33 horas
# Navio 120 terminou em 648.55 horas | Tempo de fila: 0.00, Tempo de serviço: 4.67
# Navio 119 terminou em 649.13 horas | Tempo de fila: 0.00, Tempo de serviço: 6.08
# Navio 121 começou a ser atendido no terminal 1 em 649.13 horas
# Navio 123 começou a ser atendido no terminal 8 em 651.15 horas
# Navio 125 começou a ser atendido no terminal 4 em 651.25 horas
# Navio 126 começou a ser atendido no terminal 2 em 653.97 horas
# Navio 121 terminou em 654.48 horas | Tempo de fila: 4.56, Tempo de serviço: 5.34
# Navio 124 começou a ser atendido no terminal 1 em 654.48 horas
# Navio 122 terminou em 654.65 horas | Tempo de fila: 0.00, Tempo de serviço: 6.32
# Navio 127 começou a ser atendido no terminal 7 em 655.07 horas
# Navio 123 terminou em 656.58 horas | Tempo de fila: 0.00, Tempo de serviço: 5.43
# Navio 125 terminou em 658.72 horas | Tempo de fila: 0.00, Tempo de serviço: 7.47
# Navio 127 terminou em 659.87 horas | Tempo de fila: 0.00, Tempo de serviço: 4.80
# Navio 124 terminou em 660.03 horas | Tempo de fila: 3.28, Tempo de serviço: 5.56
# Navio 126 terminou em 661.15 horas | Tempo de fila: 0.00, Tempo de serviço: 7.17
# Navio 128 começou a ser atendido no terminal 6 em 661.27 horas
# Navio 129 começou a ser atendido no terminal 10 em 664.72 horas
# Navio 128 terminou em 668.31 horas | Tempo de fila: 0.00, Tempo de serviço: 7.04
# Navio 129 terminou em 671.30 horas | Tempo de fila: 0.00, Tempo de serviço: 6.58
# Navio 130 começou a ser atendido no terminal 9 em 678.15 horas
# Navio 130 terminou em 683.13 horas | Tempo de fila: 0.00, Tempo de serviço: 4.98
# Navio 131 começou a ser atendido no terminal 8 em 693.03 horas
# Navio 132 começou a ser atendido no terminal 4 em 694.61 horas
# Navio 131 terminou em 697.71 horas | Tempo de fila: 0.00, Tempo de serviço: 4.68
# Navio 132 terminou em 701.32 horas | Tempo de fila: 0.00, Tempo de serviço: 6.71
# Navio 133 começou a ser atendido no terminal 17 em 703.60 horas
# Navio 134 começou a ser atendido no terminal 3 em 705.84 horas
# Navio 133 terminou em 711.14 horas | Tempo de fila: 0.00, Tempo de serviço: 7.54
# Navio 134 terminou em 712.33 horas | Tempo de fila: 0.00, Tempo de serviço: 6.49
# Navio 135 começou a ser atendido no terminal 13 em 713.47 horas
# Navio 136 começou a ser atendido no terminal 7 em 718.65 horas
# Navio 135 terminou em 719.34 horas | Tempo de fila: 0.00, Tempo de serviço: 5.87
# Navio 137 começou a ser atendido no terminal 19 em 719.97 horas
#
# Logs dos navios:
# <style type="text/css">
# </style>
# <table id="T_f18c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f18c2_level0_col0" class="col_heading level0 col0" >ID Navio</th>
#       <th id="T_f18c2_level0_col1" class="col_heading level0 col1" >Terminal</th>
#       <th id="T_f18c2_level0_col2" class="col_heading level0 col2" >Chegada</th>
#       <th id="T_f18c2_level0_col3" class="col_heading level0 col3" >Início Serviço</th>
#       <th id="T_f18c2_level0_col4" class="col_heading level0 col4" >Fila (h)</th>
#       <th id="T_f18c2_level0_col5" class="col_heading level0 col5" >Duração Serviço</th>
#       <th id="T_f18c2_level0_col6" class="col_heading level0 col6" >Término</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f18c2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f18c2_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_f18c2_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_f18c2_row0_col2" class="data row0 col2" >2.50</td>
#       <td id="T_f18c2_row0_col3" class="data row0 col3" >2.50</td>
#       <td id="T_f18c2_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_f18c2_row0_col5" class="data row0 col5" >7.24</td>
#       <td id="T_f18c2_row0_col6" class="data row0 col6" >9.74</td>
#     </tr>
#     <tr>
#       <th id="T_f18c2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f18c2_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_f18c2_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_f18c2_row1_col2" class="data row1 col2" >12.90</td>
#       <td id="T_f18c2_row1_col3" class="data row1 col3" >12.90</td>
#       <td id="T_f18c2_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_f18c2_row1_col5" class="data row1 col5" >5.68</td>
#       <td id="T_f18c2_row1_col6" class="data row1 col6" >18.58</td>
#     </tr>
#     <tr>
#       <th id="T_f18c2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f18c2_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_f18c2_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_f18c2_row2_col2" class="data row2 col2" >24.20</td>
#       <td id="T_f18c2_row2_col3" class="data row2 col3" >24.20</td>
#       <td id="T_f18c2_row2_col4" class="data row2 col4" >0.00</td>
#       <td id="T_f18c2_row2_col5" class="data row2 col5" >6.24</td>
#       <td id="T_f18c2_row2_col6" class="data row2 col6" >30.44</td>
#     </tr>
#     <tr>
#       <th id="T_f18c2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f18c2_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_f18c2_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_f18c2_row3_col2" class="data row3 col2" >26.31</td>
#       <td id="T_f18c2_row3_col3" class="data row3 col3" >26.31</td>
#       <td id="T_f18c2_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_f18c2_row3_col5" class="data row3 col5" >5.28</td>
#       <td id="T_f18c2_row3_col6" class="data row3 col6" >31.59</td>
#     </tr>
#     <tr>
#       <th id="T_f18c2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f18c2_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_f18c2_row4_col1" class="data row4 col1" >9</td>
#       <td id="T_f18c2_row4_col2" class="data row4 col2" >33.01</td>
#       <td id="T_f18c2_row4_col3" class="data row4 col3" >33.01</td>
#       <td id="T_f18c2_row4_col4" class="data row4 col4" >0.00</td>
#       <td id="T_f18c2_row4_col5" class="data row4 col5" >6.30</td>
#       <td id="T_f18c2_row4_col6" class="data row4 col6" >39.31</td>
#     </tr>
#     <tr>
#       <th id="T_f18c2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f18c2_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_f18c2_row5_col1" class="data row5 col1" >19</td>
#       <td id="T_f18c2_row5_col2" class="data row5 col2" >47.64</td>
#       <td id="T_f18c2_row5_col3" class="data row5 col3" >47.64</td>
#       <td id="T_f18c2_row5_col4" class="data row5 col4" >0.00</td>
#       <td id="T_f18c2_row5_col5" class="data row5 col5" >4.75</td>
#       <td id="T_f18c2_row5_col6" class="data row5 col6" >52.39</td>
#     </tr>
#     <tr>
#       <th id="T_f18c2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f18c2_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_f18c2_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_f18c2_row6_col2" class="data row6 col2" >50.16</td>
#       <td id="T_f18c2_row6_col3" class="data row6 col3" >50.16</td>
#       <td id="T_f18c2_row6_col4" class="data row6 col4" >0.00</td>
#       <td id="T_f18c2_row6_col5" class="data row6 col5" >6.25</td>
#       <td id="T_f18c2_row6_col6" class="data row6 col6" >56.41</td>
#     </tr>
#     <tr>
#       <th id="T_f18c2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f18c2_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_f18c2_row7_col1" class="data row7 col1" >6</td>
#       <td id="T_f18c2_row7_col2" class="data row7 col2" >52.47</td>
#       <td id="T_f18c2_row7_col3" class="data row7 col3" >52.47</td>
#       <td id="T_f18c2_row7_col4" class="data row7 col4" >0.00</td>
#       <td id="T_f18c2_row7_col5" class="data row7 col5" >5.17</td>
#       <td id="T_f18c2_row7_col6" class="data row7 col6" >57.64</td>
#     </tr>
#     <tr>
#       <th id="T_f18c2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f18c2_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_f18c2_row8_col1" class="data row8 col1" >11</td>
#       <td id="T_f18c2_row8_col2" class="data row8 col2" >53.44</td>
#       <td id="T_f18c2_row8_col3" class="data row8 col3" >53.44</td>
#       <td id="T_f18c2_row8_col4" class="data row8 col4" >0.00</td>
#       <td id="T_f18c2_row8_col5" class="data row8 col5" >7.49</td>
#       <td id="T_f18c2_row8_col6" class="data row8 col6" >60.94</td>
#     </tr>
#     <tr>
#       <th id="T_f18c2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f18c2_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_f18c2_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_f18c2_row9_col2" class="data row9 col2" >59.04</td>
#       <td id="T_f18c2_row9_col3" class="data row9 col3" >59.04</td>
#       <td id="T_f18c2_row9_col4" class="data row9 col4" >0.00</td>
#       <td id="T_f18c2_row9_col5" class="data row9 col5" >5.41</td>
#       <td id="T_f18c2_row9_col6" class="data row9 col6" >64.45</td>
#     </tr>
#   </tbody>
# </table>
# Logs dos terminais:
# <style type="text/css">
# </style>
# <table id="T_4b5af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b5af_level0_col0" class="col_heading level0 col0" >Terminal</th>
#       <th id="T_4b5af_level0_col1" class="col_heading level0 col1" >Tempo Ocioso (h)</th>
#       <th id="T_4b5af_level0_col2" class="col_heading level0 col2" >Tempo Total (h)</th>
#       <th id="T_4b5af_level0_col3" class="col_heading level0 col3" >Ocupação (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b5af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b5af_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_4b5af_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_4b5af_row0_col2" class="data row0 col2" >720</td>
#       <td id="T_4b5af_row0_col3" class="data row0 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4b5af_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_4b5af_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_4b5af_row1_col2" class="data row1 col2" >720</td>
#       <td id="T_4b5af_row1_col3" class="data row1 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4b5af_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_4b5af_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_4b5af_row2_col2" class="data row2 col2" >720</td>
#       <td id="T_4b5af_row2_col3" class="data row2 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4b5af_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_4b5af_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_4b5af_row3_col2" class="data row3 col2" >720</td>
#       <td id="T_4b5af_row3_col3" class="data row3 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4b5af_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_4b5af_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_4b5af_row4_col2" class="data row4 col2" >720</td>
#       <td id="T_4b5af_row4_col3" class="data row4 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4b5af_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_4b5af_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_4b5af_row5_col2" class="data row5 col2" >720</td>
#       <td id="T_4b5af_row5_col3" class="data row5 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4b5af_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_4b5af_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_4b5af_row6_col2" class="data row6 col2" >720</td>
#       <td id="T_4b5af_row6_col3" class="data row6 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4b5af_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_4b5af_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_4b5af_row7_col2" class="data row7 col2" >720</td>
#       <td id="T_4b5af_row7_col3" class="data row7 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4b5af_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_4b5af_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_4b5af_row8_col2" class="data row8 col2" >720</td>
#       <td id="T_4b5af_row8_col3" class="data row8 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4b5af_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_4b5af_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_4b5af_row9_col2" class="data row9 col2" >720</td>
#       <td id="T_4b5af_row9_col3" class="data row9 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4b5af_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_4b5af_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_4b5af_row10_col2" class="data row10 col2" >720</td>
#       <td id="T_4b5af_row10_col3" class="data row10 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4b5af_row11_col0" class="data row11 col0" >11</td>
#       <td id="T_4b5af_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_4b5af_row11_col2" class="data row11 col2" >720</td>
#       <td id="T_4b5af_row11_col3" class="data row11 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4b5af_row12_col0" class="data row12 col0" >12</td>
#       <td id="T_4b5af_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_4b5af_row12_col2" class="data row12 col2" >720</td>
#       <td id="T_4b5af_row12_col3" class="data row12 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4b5af_row13_col0" class="data row13 col0" >13</td>
#       <td id="T_4b5af_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_4b5af_row13_col2" class="data row13 col2" >720</td>
#       <td id="T_4b5af_row13_col3" class="data row13 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4b5af_row14_col0" class="data row14 col0" >14</td>
#       <td id="T_4b5af_row14_col1" class="data row14 col1" >0</td>
#       <td id="T_4b5af_row14_col2" class="data row14 col2" >720</td>
#       <td id="T_4b5af_row14_col3" class="data row14 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4b5af_row15_col0" class="data row15 col0" >15</td>
#       <td id="T_4b5af_row15_col1" class="data row15 col1" >0</td>
#       <td id="T_4b5af_row15_col2" class="data row15 col2" >720</td>
#       <td id="T_4b5af_row15_col3" class="data row15 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4b5af_row16_col0" class="data row16 col0" >16</td>
#       <td id="T_4b5af_row16_col1" class="data row16 col1" >0</td>
#       <td id="T_4b5af_row16_col2" class="data row16 col2" >720</td>
#       <td id="T_4b5af_row16_col3" class="data row16 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4b5af_row17_col0" class="data row17 col0" >17</td>
#       <td id="T_4b5af_row17_col1" class="data row17 col1" >0</td>
#       <td id="T_4b5af_row17_col2" class="data row17 col2" >720</td>
#       <td id="T_4b5af_row17_col3" class="data row17 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4b5af_row18_col0" class="data row18 col0" >18</td>
#       <td id="T_4b5af_row18_col1" class="data row18 col1" >0</td>
#       <td id="T_4b5af_row18_col2" class="data row18 col2" >720</td>
#       <td id="T_4b5af_row18_col3" class="data row18 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_4b5af_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4b5af_row19_col0" class="data row19 col0" >19</td>
#       <td id="T_4b5af_row19_col1" class="data row19 col1" >0</td>
#       <td id="T_4b5af_row19_col2" class="data row19 col2" >720</td>
#       <td id="T_4b5af_row19_col3" class="data row19 col3" >100.00</td>
#     </tr>
#   </tbody>
# </table>
